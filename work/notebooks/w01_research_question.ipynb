# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gullahmadbhatti0155/MLtask1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Search Ranking and Content Performance
#
# I chose this lane because I want to understand how search ranking and click-through rate (CTR) affect the performance of web pages. By analyzing these metrics, I can identify pages that need improvement and help make better decisions for content optimization.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).


# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Research Question
#
# **Decision:** Decide which web pages should be improved to increase search performance.
#
# **Action:** A content manager or SEO specialist updates pages with low CTR or poor search ranking to improve their visibility.
#
# **Cost of a wrong call:** If the recommendation is wrong, time and effort may be spent improving pages that do not need changes, while pages that actually need improvement are ignored. This can reduce traffic and waste resources.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# From the starter dataset, I will use metrics such as CTR, average position, and impressions to understand content performance. These numbers will help identify pages that have good visibility but low CTR, or poor rankings that may need optimization. This makes the research question useful for the next several weeks.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Careful Words
#
# This project can identify patterns and relationships in the data that may help support decisions about improving web page performance. The results are observational and directional, and they can help prioritize which pages to review.
#
# This project cannot prove that one factor directly causes another, and it cannot predict or explain Google's search algorithm. The findings should be used as decision support rather than as proof of cause and effect.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
